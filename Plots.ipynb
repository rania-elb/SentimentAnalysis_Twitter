# %%
import matplotlib.pyplot as plt
import numpy as np
#import utils
import pickle
# %matplotlib inline

# %%
FREQ_DIST_FILE = 'C:\\Users\\hp\\Documents\\Projects5\\code\\twitter-sentiment-analysis-master\\Dataset3-processed-freqdist.pkl'
BI_FREQ_DIST_FILE = 'C:\\Users\\hp\\Documents\\Projects5\code\\twitter-sentiment-analysis-master\\Dataset3-processed-freqdist-bi.pkl'

# %%
with open(FREQ_DIST_FILE, 'rb') as pkl_file:
    freq_dist = pickle.load(pkl_file)
unigrams = freq_dist.most_common(20)
unigrams
# Out:
# [('i', 3536),
#  ('to', 2605),
#  ('the', 2482),
#  ('a', 1894),
#  ('my', 1760),
#  ('and', 1632),
#  ('is', 1295),
#  ('in', 1070),
#  ('it', 1033),
#  ('for', 1012),
#  ('you', 1005),
#  ('of', 1005),
#  ('me', 956),
#  ('on', 852),
#  ('im', 767),
#  ('so', 718),
#  ('that', 642),
#  ('have', 610),
#  ('this', 607),
#  ('be', 564)]

# %%
plt.figure(1, [10, 7])
x = np.array(range(0, 40, 2))
y = np.array([i[1] for i in unigrams])
my_xticks = [i[0] for i in unigrams]
plt.xticks(x, my_xticks, rotation=90)
plt.plot(x, y)
plt.show()

# %%
with open(BI_FREQ_DIST_FILE, 'rb') as pkl_file:
    freq_dist = pickle.load(pkl_file)
bigrams = freq_dist.most_common(20)
bigrams
# Out:
# [(('in', 'the'), 234),
#  (('i', 'have'), 197),
#  (('i', 'love'), 174),
#  (('i', 'dont'), 167),
#  (('going', 'to'), 159),
#  (('for', 'the'), 157),
#  (('to', 'be'), 148),
#  (('and', 'i'), 147),
#  (('of', 'the'), 137),
#  (('have', 'to'), 130),
#  (('i', 'cant'), 129),
#  (('i', 'want'), 128),
#  (('i', 'am'), 124),
#  (('on', 'the'), 123),
#  (('want', 'to'), 119),
#  (('to', 'go'), 118),
#  (('to', 'the'), 115),
#  (('i', 'miss'), 112),
#  (('i', 'think'), 106),
#  (('but', 'i'), 103)]

# %%
plt.figure(1, [10, 7])
x = np.array(range(0, 40, 2))
y = np.array([i[1] for i in bigrams])
my_xticks = [', '.join(i[0]) for i in bigrams]
plt.xticks(x, my_xticks, rotation=90)
plt.plot(x, y)
plt.show()

# %%
with open(FREQ_DIST_FILE, 'rb') as pkl_file:
    freq_dist = pickle.load(pkl_file)
unigrams = freq_dist.most_common(100)
log_ranks = np.log(range(1, 101))
log_freqs = np.log([i[1] for i in unigrams])
z = np.polyfit(log_ranks, log_freqs, 1)
p = np.poly1d(z)
p
# Out:
# poly1d([-0.78896515,  8.67156663])

# %%
plt.figure(3, [8,6])
plt.plot(log_ranks, log_freqs, 'ro')
plt.plot(log_ranks,p(log_ranks),'b-')
plt.xlabel('log (Rank)')
plt.ylabel('log (Freqeuncy)')
plt.title('Zipf\'s Law')
plt.show()

# %%
classifiers = ['Logistic Regression', 'Naive Bayes', 'Decision Tree', 'Random Forest', 'SVM']
accuracies = [69.7, 79.68,68.1, 77.21,81.55]
plt.figure(4, [8,6])
plt.bar(range(len(classifiers)), accuracies, align='center', alpha=0.5)
plt.xticks(range(len(classifiers)), classifiers, rotation=90)
plt.ylabel('Accuracy')
plt.title('Comparison of Various Classifiers')
plt.ylim([60, 90])
plt.show()
